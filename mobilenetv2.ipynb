# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pip install split-folders
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
########### splitting data ############
import splitfolders
splitfolders.ratio('/kaggle/input/audataset/AugmentedAlzheimerDataset', output="Inputs", seed=1345, ratio=(0.7,0.2,0.1))# seed was 1345
SAMPLE_PER_CATEGORY = 200
SEED = 42
WIDTH = 128
HEIGHT = 128
DEPTH = 3
INPUT_SHAPE = (WIDTH, HEIGHT, DEPTH)
# Out:
# Copying files: 33984 files [04:19, 130.75 files/s]

# %%
# Paths
train_dir = '/kaggle/working/Inputs/train'  # Set path to train directory
test_dir = '/kaggle/working/Inputs/test'  # Set path to test directory

# Hyperparameters
batch_size = 32
epochs = 50
dropout_rate = 0.2
image_size = (128, 128)

# Data Generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 19032 images belonging to 4 classes.
# Found 4756 images belonging to 4 classes.
# Found 3400 images belonging to 4 classes.

# %%
# Model Definition
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128,128, 3))
base_model.trainable = False  # Freeze the base model

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(dropout_rate),
    Dense(4, activation='softmax')  # 4 classes
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Training
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731968627.044607     180 service.cc:145] XLA service 0x7bc06403cc30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731968627.044692     180 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1731968627.044698     180 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   3/595 ━━━━━━━━━━━━━━━━━━━━ 41s 71ms/step - accuracy: 0.2153 - loss: 2.2561
# I0000 00:00:1731968633.877258     180 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 113s 170ms/step - accuracy: 0.3788 - loss: 1.3916 - val_accuracy: 0.5166 - val_loss: 1.0712 - learning_rate: 0.0010
# Epoch 2/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.4980 - loss: 1.1151 - val_accuracy: 0.5713 - val_loss: 0.9904 - learning_rate: 0.0010
# Epoch 3/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5127 - loss: 1.0757 - val_accuracy: 0.5513 - val_loss: 1.0242 - learning_rate: 0.0010
# Epoch 4/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5355 - loss: 1.0439 - val_accuracy: 0.5622 - val_loss: 0.9995 - learning_rate: 0.0010
# Epoch 5/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5443 - loss: 1.0303 - val_accuracy: 0.5860 - val_loss: 0.9645 - learning_rate: 0.0010
# Epoch 6/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5337 - loss: 1.0413 - val_accuracy: 0.5782 - val_loss: 0.9503 - learning_rate: 0.0010
# Epoch 7/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5478 - loss: 1.0248 - val_accuracy: 0.5387 - val_loss: 0.9997 - learning_rate: 0.0010
# Epoch 8/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5483 - loss: 1.0183 - val_accuracy: 0.5763 - val_loss: 0.9385 - learning_rate: 0.0010
# Epoch 9/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 153ms/step - accuracy: 0.5468 - loss: 1.0299 - val_accuracy: 0.5448 - val_loss: 0.9780 - learning_rate: 0.0010
# Epoch 10/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 153ms/step - accuracy: 0.5428 - loss: 1.0357 - val_accuracy: 0.5925 - val_loss: 0.9353 - learning_rate: 0.0010
# Epoch 11/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5436 - loss: 1.0199 - val_accuracy: 0.5875 - val_loss: 0.9300 - learning_rate: 0.0010
# Epoch 12/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.5487 - loss: 1.0206 - val_accuracy: 0.5456 - val_loss: 1.0150 - learning_rate: 0.0010
# Epoch 13/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.5500 - loss: 1.0143 - val_accuracy: 0.5643 - val_loss: 0.9697 - learning_rate: 0.0010
# Epoch 14/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5404 - loss: 1.0255 - val_accuracy: 0.5944 - val_loss: 0.9196 - learning_rate: 0.0010
# Epoch 15/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5465 - loss: 1.0241 - val_accuracy: 0.5845 - val_loss: 0.9403 - learning_rate: 0.0010
# Epoch 16/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5503 - loss: 1.0165 - val_accuracy: 0.6022 - val_loss: 0.9321 - learning_rate: 0.0010
# Epoch 17/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.5525 - loss: 1.0073 - val_accuracy: 0.5915 - val_loss: 0.9379 - learning_rate: 0.0010
# Epoch 18/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.5552 - loss: 1.0013 - val_accuracy: 0.6005 - val_loss: 0.9111 - learning_rate: 5.0000e-04
# Epoch 19/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.5648 - loss: 0.9938 - val_accuracy: 0.6034 - val_loss: 0.9078 - learning_rate: 5.0000e-04
# Epoch 20/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.5581 - loss: 1.0033 - val_accuracy: 0.5885 - val_loss: 0.9240 - learning_rate: 5.0000e-04
# Epoch 21/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.5632 - loss: 0.9924 - val_accuracy: 0.5988 - val_loss: 0.9077 - learning_rate: 5.0000e-04
# Epoch 22/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5729 - loss: 0.9852 - val_accuracy: 0.5889 - val_loss: 0.9458 - learning_rate: 5.0000e-04
# Epoch 23/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5711 - loss: 0.9746 - val_accuracy: 0.6030 - val_loss: 0.9085 - learning_rate: 2.5000e-04
# Epoch 24/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5693 - loss: 0.9866 - val_accuracy: 0.5971 - val_loss: 0.9158 - learning_rate: 2.5000e-04
# Epoch 25/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.5689 - loss: 0.9765 - val_accuracy: 0.6005 - val_loss: 0.9227 - learning_rate: 2.5000e-04
# Epoch 26/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.5787 - loss: 0.9668 - val_accuracy: 0.6112 - val_loss: 0.8994 - learning_rate: 1.2500e-04
# Epoch 27/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5672 - loss: 0.9824 - val_accuracy: 0.6047 - val_loss: 0.9053 - learning_rate: 1.2500e-04
# Epoch 28/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5774 - loss: 0.9744 - val_accuracy: 0.6161 - val_loss: 0.8981 - learning_rate: 1.2500e-04
# Epoch 29/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5683 - loss: 0.9773 - val_accuracy: 0.6068 - val_loss: 0.9051 - learning_rate: 1.2500e-04
# Epoch 30/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5759 - loss: 0.9751 - val_accuracy: 0.6077 - val_loss: 0.9066 - learning_rate: 1.2500e-04
# Epoch 31/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 156ms/step - accuracy: 0.5701 - loss: 0.9713 - val_accuracy: 0.5877 - val_loss: 0.9257 - learning_rate: 1.2500e-04
# Epoch 32/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.5775 - loss: 0.9722 - val_accuracy: 0.6058 - val_loss: 0.9079 - learning_rate: 6.2500e-05
# Epoch 33/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.5754 - loss: 0.9666 - val_accuracy: 0.6156 - val_loss: 0.9033 - learning_rate: 6.2500e-05

# %%
# Evaluation
train_loss, train_acc = model.evaluate(train_generator, verbose=0)
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Train Accuracy: {train_acc:.2f}, Test Accuracy: {test_acc:.2f}")
# Out:
# Train Accuracy: 0.61, Test Accuracy: 0.56
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.64      0.42      0.51       896
# ModerateDemented       0.88      0.70      0.78       648
#      NonDemented       0.48      0.85      0.61       960
# VeryMildDemented       0.44      0.29      0.35       896
#
#         accuracy                           0.56      3400
#        macro avg       0.61      0.56      0.56      3400
#     weighted avg       0.59      0.56      0.55      3400

# %%
# Classification Report and Confusion Matrix
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.64      0.42      0.51       896
# ModerateDemented       0.88      0.70      0.78       648
#      NonDemented       0.48      0.85      0.61       960
# VeryMildDemented       0.44      0.29      0.35       896
#
#         accuracy                           0.56      3400
#        macro avg       0.61      0.56      0.56      3400
#     weighted avg       0.59      0.56      0.55      3400

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(class_labels)):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(len(class_labels)):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Plotting Loss and Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
