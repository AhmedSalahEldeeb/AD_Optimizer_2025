# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pip install split-folders
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
########### splitting data ############
import splitfolders
splitfolders.ratio('/kaggle/input/audataset/AugmentedAlzheimerDataset', output="Inputs", seed=1345, ratio=(0.7,0.2,0.1))# seed was 1345
SAMPLE_PER_CATEGORY = 200
SEED = 42
WIDTH = 128
HEIGHT = 128
DEPTH = 3
INPUT_SHAPE = (WIDTH, HEIGHT, DEPTH)
# Out:
# Copying files: 33984 files [05:34, 101.62 files/s]

# %%
# Paths
train_dir = '/kaggle/working/Inputs/train'  # Set path to train directory
test_dir = '/kaggle/working/Inputs/test'  # Set path to test directory

# Hyperparameters
batch_size = 32
epochs = 30
dropout_rate = 0.2
image_size = (128, 128)

# Data Generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 19032 images belonging to 4 classes.
# Found 4756 images belonging to 4 classes.
# Found 3400 images belonging to 4 classes.

# %%
# Model Definition
base_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(128,128, 3))
#base_model.trainable = False  # Freeze the base model
for layers in base_model.layers[:100]:
    layers.trainable = False
for layers in base_model.layers[100:]:
    layers.trainable = True


model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(dropout_rate),
    Dense(4, activation='softmax')  # 4 classes
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Training
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732325162.528264     121 service.cc:145] XLA service 0x79cc8c003660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732325162.528334     121 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1732325162.528340     121 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732325212.107366     121 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_52', 40 bytes spill stores, 40 bytes spill loads
#
# I0000 00:00:1732325212.184045     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 321s 353ms/step - accuracy: 0.4742 - loss: 1.1171 - val_accuracy: 0.5444 - val_loss: 1.0389 - learning_rate: 0.0010
# Epoch 2/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 260ms/step - accuracy: 0.6472 - loss: 0.7510 - val_accuracy: 0.5008 - val_loss: 1.9688 - learning_rate: 0.0010
# Epoch 3/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 260ms/step - accuracy: 0.6872 - loss: 0.6904 - val_accuracy: 0.6703 - val_loss: 0.7299 - learning_rate: 0.0010
# Epoch 4/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 260ms/step - accuracy: 0.7114 - loss: 0.6357 - val_accuracy: 0.7172 - val_loss: 0.6362 - learning_rate: 0.0010
# Epoch 5/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 260ms/step - accuracy: 0.7263 - loss: 0.5969 - val_accuracy: 0.7334 - val_loss: 0.5686 - learning_rate: 0.0010
# Epoch 6/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 261ms/step - accuracy: 0.7517 - loss: 0.5617 - val_accuracy: 0.7309 - val_loss: 0.6465 - learning_rate: 0.0010
# Epoch 7/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.7645 - loss: 0.5314 - val_accuracy: 0.7563 - val_loss: 0.6010 - learning_rate: 0.0010
# Epoch 8/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 260ms/step - accuracy: 0.7797 - loss: 0.5062 - val_accuracy: 0.7706 - val_loss: 0.5361 - learning_rate: 0.0010
# Epoch 9/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 260ms/step - accuracy: 0.8023 - loss: 0.4499 - val_accuracy: 0.8106 - val_loss: 0.4239 - learning_rate: 0.0010
# Epoch 10/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.8189 - loss: 0.4268 - val_accuracy: 0.8061 - val_loss: 0.4342 - learning_rate: 0.0010
# Epoch 11/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 258ms/step - accuracy: 0.8260 - loss: 0.4081 - val_accuracy: 0.7984 - val_loss: 0.4789 - learning_rate: 0.0010
# Epoch 12/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 257ms/step - accuracy: 0.8211 - loss: 0.4422 - val_accuracy: 0.8335 - val_loss: 0.4392 - learning_rate: 0.0010
# Epoch 13/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 258ms/step - accuracy: 0.8579 - loss: 0.3385 - val_accuracy: 0.8625 - val_loss: 0.3139 - learning_rate: 2.0000e-04
# Epoch 14/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 258ms/step - accuracy: 0.8789 - loss: 0.2938 - val_accuracy: 0.8825 - val_loss: 0.2844 - learning_rate: 2.0000e-04
# Epoch 15/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.8843 - loss: 0.2766 - val_accuracy: 0.8928 - val_loss: 0.2496 - learning_rate: 2.0000e-04
# Epoch 16/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.8942 - loss: 0.2525 - val_accuracy: 0.8938 - val_loss: 0.2536 - learning_rate: 2.0000e-04
# Epoch 17/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.8997 - loss: 0.2596 - val_accuracy: 0.8993 - val_loss: 0.2353 - learning_rate: 2.0000e-04
# Epoch 18/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.9087 - loss: 0.2276 - val_accuracy: 0.9020 - val_loss: 0.2370 - learning_rate: 2.0000e-04
# Epoch 19/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.9130 - loss: 0.2161 - val_accuracy: 0.9043 - val_loss: 0.2338 - learning_rate: 2.0000e-04
# Epoch 20/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 258ms/step - accuracy: 0.9143 - loss: 0.2081 - val_accuracy: 0.9203 - val_loss: 0.2018 - learning_rate: 2.0000e-04
# Epoch 21/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 257ms/step - accuracy: 0.9173 - loss: 0.2061 - val_accuracy: 0.9201 - val_loss: 0.2134 - learning_rate: 2.0000e-04
# Epoch 22/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 257ms/step - accuracy: 0.9246 - loss: 0.1839 - val_accuracy: 0.9302 - val_loss: 0.1746 - learning_rate: 2.0000e-04
# Epoch 23/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 257ms/step - accuracy: 0.9345 - loss: 0.1711 - val_accuracy: 0.9188 - val_loss: 0.1989 - learning_rate: 2.0000e-04
# Epoch 24/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 153s 256ms/step - accuracy: 0.9346 - loss: 0.1643 - val_accuracy: 0.9336 - val_loss: 0.1749 - learning_rate: 2.0000e-04
# Epoch 25/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 257ms/step - accuracy: 0.9361 - loss: 0.1628 - val_accuracy: 0.9386 - val_loss: 0.1515 - learning_rate: 2.0000e-04
# Epoch 26/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 154s 258ms/step - accuracy: 0.9406 - loss: 0.1547 - val_accuracy: 0.9308 - val_loss: 0.1772 - learning_rate: 2.0000e-04
# Epoch 27/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.9456 - loss: 0.1422 - val_accuracy: 0.9321 - val_loss: 0.1723 - learning_rate: 2.0000e-04
# Epoch 28/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.9465 - loss: 0.1400 - val_accuracy: 0.9357 - val_loss: 0.1658 - learning_rate: 2.0000e-04
# Epoch 29/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 155s 259ms/step - accuracy: 0.9496 - loss: 0.1298 - val_accuracy: 0.9525 - val_loss: 0.1225 - learning_rate: 4.0000e-05
# Epoch 30/30
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 156s 260ms/step - accuracy: 0.9568 - loss: 0.1109 - val_accuracy: 0.9504 - val_loss: 0.1201 - learning_rate: 4.0000e-05

# %%
# Evaluation
train_loss, train_acc = model.evaluate(train_generator, verbose=0)
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Train Accuracy: {train_acc:.2f}, Test Accuracy: {test_acc:.2f}")
# Out:
# Train Accuracy: 0.96, Test Accuracy: 0.97

# %%
# Classification Report and Confusion Matrix
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 21s 129ms/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.99      0.99      0.99       896
# ModerateDemented       1.00      1.00      1.00       648
#      NonDemented       0.95      0.97      0.96       960
# VeryMildDemented       0.96      0.94      0.95       896
#
#         accuracy                           0.97      3400
#        macro avg       0.97      0.97      0.97      3400
#     weighted avg       0.97      0.97      0.97      3400

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(class_labels)):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(len(class_labels)):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Plotting Loss and Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
