# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pip install split-folders
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
########### splitting data ############
import splitfolders
splitfolders.ratio('/kaggle/input/audataset/AugmentedAlzheimerDataset', output="Inputs", seed=1345, ratio=(0.7,0.2,0.1))# seed was 1345
SAMPLE_PER_CATEGORY = 200
SEED = 42
WIDTH = 128
HEIGHT = 128
DEPTH = 3
INPUT_SHAPE = (WIDTH, HEIGHT, DEPTH)
# Out:
# Copying files: 33984 files [04:07, 137.28 files/s]

# %%
# Paths
train_dir = '/kaggle/working/Inputs/train'  # Set path to train directory
test_dir = '/kaggle/working/Inputs/test'  # Set path to test directory

# Hyperparameters
batch_size = 32
epochs = 50
dropout_rate = 0.2
image_size = (128, 128)

# Data Generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 19032 images belonging to 4 classes.
# Found 4756 images belonging to 4 classes.
# Found 3400 images belonging to 4 classes.

# %%
# Model Definition
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(128,128, 3))
#base_model.trainable = False  # Freeze the base model
for layers in base_model.layers[:100]:
    layers.trainable = False
for layers in base_model.layers[100:]:
    layers.trainable = True


model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(dropout_rate),
    Dense(4, activation='softmax')  # 4 classes
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Training
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732051583.642417     121 service.cc:145] XLA service 0x7ee5c4060fd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732051583.642491     121 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1732051583.642496     121 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   1/595 ━━━━━━━━━━━━━━━━━━━━ 4:56:39 30s/step - accuracy: 0.2500 - loss: 1.7152
# I0000 00:00:1732051597.708911     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 148s 199ms/step - accuracy: 0.5191 - loss: 1.0496 - val_accuracy: 0.5967 - val_loss: 0.7872 - learning_rate: 0.0010
# Epoch 2/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 102s 169ms/step - accuracy: 0.6825 - loss: 0.7012 - val_accuracy: 0.7101 - val_loss: 0.6277 - learning_rate: 0.0010
# Epoch 3/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.7104 - loss: 0.6448 - val_accuracy: 0.6989 - val_loss: 0.6952 - learning_rate: 0.0010
# Epoch 4/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 169ms/step - accuracy: 0.7534 - loss: 0.5682 - val_accuracy: 0.7477 - val_loss: 0.6035 - learning_rate: 0.0010
# Epoch 5/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 169ms/step - accuracy: 0.7672 - loss: 0.5260 - val_accuracy: 0.7719 - val_loss: 0.5089 - learning_rate: 0.0010
# Epoch 6/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 102s 170ms/step - accuracy: 0.7957 - loss: 0.4792 - val_accuracy: 0.7897 - val_loss: 0.4912 - learning_rate: 0.0010
# Epoch 7/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 102s 170ms/step - accuracy: 0.8147 - loss: 0.4452 - val_accuracy: 0.8143 - val_loss: 0.4242 - learning_rate: 0.0010
# Epoch 8/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 102s 169ms/step - accuracy: 0.8244 - loss: 0.4117 - val_accuracy: 0.8135 - val_loss: 0.4447 - learning_rate: 0.0010
# Epoch 9/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.8458 - loss: 0.3654 - val_accuracy: 0.8373 - val_loss: 0.3667 - learning_rate: 0.0010
# Epoch 10/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.8664 - loss: 0.3333 - val_accuracy: 0.8627 - val_loss: 0.3452 - learning_rate: 0.0010
# Epoch 11/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.8701 - loss: 0.3197 - val_accuracy: 0.8631 - val_loss: 0.3148 - learning_rate: 0.0010
# Epoch 12/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 169ms/step - accuracy: 0.8869 - loss: 0.2873 - val_accuracy: 0.8690 - val_loss: 0.3292 - learning_rate: 0.0010
# Epoch 13/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.8918 - loss: 0.2733 - val_accuracy: 0.8623 - val_loss: 0.3768 - learning_rate: 0.0010
# Epoch 14/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.8964 - loss: 0.2674 - val_accuracy: 0.9026 - val_loss: 0.2480 - learning_rate: 0.0010
# Epoch 15/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 102s 169ms/step - accuracy: 0.9097 - loss: 0.2280 - val_accuracy: 0.8926 - val_loss: 0.2572 - learning_rate: 0.0010
# Epoch 16/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.9184 - loss: 0.2154 - val_accuracy: 0.9075 - val_loss: 0.2290 - learning_rate: 0.0010
# Epoch 17/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9232 - loss: 0.1966 - val_accuracy: 0.9260 - val_loss: 0.1917 - learning_rate: 0.0010
# Epoch 18/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.9258 - loss: 0.1869 - val_accuracy: 0.9249 - val_loss: 0.1886 - learning_rate: 0.0010
# Epoch 19/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 169ms/step - accuracy: 0.9319 - loss: 0.1750 - val_accuracy: 0.9302 - val_loss: 0.1762 - learning_rate: 0.0010
# Epoch 20/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 167ms/step - accuracy: 0.9353 - loss: 0.1699 - val_accuracy: 0.9310 - val_loss: 0.1773 - learning_rate: 0.0010
# Epoch 21/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.9420 - loss: 0.1537 - val_accuracy: 0.9367 - val_loss: 0.1705 - learning_rate: 0.0010
# Epoch 22/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9336 - loss: 0.1783 - val_accuracy: 0.9485 - val_loss: 0.1385 - learning_rate: 0.0010
# Epoch 23/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9455 - loss: 0.1477 - val_accuracy: 0.9378 - val_loss: 0.1649 - learning_rate: 0.0010
# Epoch 24/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9489 - loss: 0.1435 - val_accuracy: 0.9434 - val_loss: 0.1494 - learning_rate: 0.0010
# Epoch 25/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9492 - loss: 0.1356 - val_accuracy: 0.9500 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 26/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9537 - loss: 0.1271 - val_accuracy: 0.9485 - val_loss: 0.1340 - learning_rate: 0.0010
# Epoch 27/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9547 - loss: 0.1283 - val_accuracy: 0.9514 - val_loss: 0.1197 - learning_rate: 0.0010
# Epoch 28/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.9551 - loss: 0.1263 - val_accuracy: 0.9464 - val_loss: 0.1372 - learning_rate: 0.0010
# Epoch 29/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 167ms/step - accuracy: 0.9568 - loss: 0.1171 - val_accuracy: 0.9418 - val_loss: 0.1388 - learning_rate: 0.0010
# Epoch 30/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.9595 - loss: 0.1121 - val_accuracy: 0.9636 - val_loss: 0.0988 - learning_rate: 0.0010
# Epoch 31/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9617 - loss: 0.1038 - val_accuracy: 0.9613 - val_loss: 0.1137 - learning_rate: 0.0010
# Epoch 32/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 168ms/step - accuracy: 0.9611 - loss: 0.1035 - val_accuracy: 0.9489 - val_loss: 0.1523 - learning_rate: 0.0010
# Epoch 33/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9571 - loss: 0.1082 - val_accuracy: 0.9537 - val_loss: 0.1218 - learning_rate: 0.0010
# Epoch 34/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 101s 167ms/step - accuracy: 0.9704 - loss: 0.0804 - val_accuracy: 0.9731 - val_loss: 0.0668 - learning_rate: 2.0000e-04
# Epoch 35/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9785 - loss: 0.0586 - val_accuracy: 0.9762 - val_loss: 0.0707 - learning_rate: 2.0000e-04
# Epoch 36/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9807 - loss: 0.0530 - val_accuracy: 0.9748 - val_loss: 0.0736 - learning_rate: 2.0000e-04
# Epoch 37/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9831 - loss: 0.0446 - val_accuracy: 0.9781 - val_loss: 0.0629 - learning_rate: 2.0000e-04
# Epoch 38/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9817 - loss: 0.0496 - val_accuracy: 0.9794 - val_loss: 0.0585 - learning_rate: 2.0000e-04
# Epoch 39/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9864 - loss: 0.0371 - val_accuracy: 0.9798 - val_loss: 0.0578 - learning_rate: 2.0000e-04
# Epoch 40/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9846 - loss: 0.0429 - val_accuracy: 0.9865 - val_loss: 0.0420 - learning_rate: 2.0000e-04
# Epoch 41/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 99s 165ms/step - accuracy: 0.9887 - loss: 0.0349 - val_accuracy: 0.9815 - val_loss: 0.0518 - learning_rate: 2.0000e-04
# Epoch 42/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9853 - loss: 0.0401 - val_accuracy: 0.9834 - val_loss: 0.0457 - learning_rate: 2.0000e-04
# Epoch 43/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 99s 165ms/step - accuracy: 0.9852 - loss: 0.0422 - val_accuracy: 0.9809 - val_loss: 0.0520 - learning_rate: 2.0000e-04
# Epoch 44/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 99s 165ms/step - accuracy: 0.9893 - loss: 0.0312 - val_accuracy: 0.9863 - val_loss: 0.0371 - learning_rate: 4.0000e-05
# Epoch 45/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9876 - loss: 0.0323 - val_accuracy: 0.9840 - val_loss: 0.0451 - learning_rate: 4.0000e-05
# Epoch 46/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9898 - loss: 0.0279 - val_accuracy: 0.9872 - val_loss: 0.0384 - learning_rate: 4.0000e-05
# Epoch 47/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9891 - loss: 0.0312 - val_accuracy: 0.9853 - val_loss: 0.0412 - learning_rate: 4.0000e-05
# Epoch 48/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9892 - loss: 0.0282 - val_accuracy: 0.9878 - val_loss: 0.0369 - learning_rate: 8.0000e-06
# Epoch 49/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 167ms/step - accuracy: 0.9911 - loss: 0.0249 - val_accuracy: 0.9886 - val_loss: 0.0315 - learning_rate: 8.0000e-06
# Epoch 50/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 100s 166ms/step - accuracy: 0.9897 - loss: 0.0294 - val_accuracy: 0.9861 - val_loss: 0.0353 - learning_rate: 8.0000e-06

# %%
# Evaluation
train_loss, train_acc = model.evaluate(train_generator, verbose=0)
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Train Accuracy: {train_acc:.2f}, Test Accuracy: {test_acc:.2f}")
# Out:
# Train Accuracy: 0.99, Test Accuracy: 0.99

# %%
# Classification Report and Confusion Matrix
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.99      1.00      1.00       896
# ModerateDemented       1.00      1.00      1.00       648
#      NonDemented       0.99      0.99      0.99       960
# VeryMildDemented       0.99      0.98      0.99       896
#
#         accuracy                           0.99      3400
#        macro avg       0.99      0.99      0.99      3400
#     weighted avg       0.99      0.99      0.99      3400

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(class_labels)):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(len(class_labels)):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Plotting Loss and Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
