# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pip install split-folders
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
########### splitting data ############
import splitfolders
splitfolders.ratio('/kaggle/input/audataset/AugmentedAlzheimerDataset', output="Inputs", seed=1345, ratio=(0.7,0.2,0.1))# seed was 1345
SAMPLE_PER_CATEGORY = 200
SEED = 42
WIDTH = 128
HEIGHT = 128
DEPTH = 3
INPUT_SHAPE = (WIDTH, HEIGHT, DEPTH)
# Out:
# Copying files: 33984 files [03:54, 145.07 files/s]

# %%
# Paths
train_dir = '/kaggle/working/Inputs/train'  # Set path to train directory
test_dir = '/kaggle/working/Inputs/test'  # Set path to test directory

# Hyperparameters
batch_size = 32
epochs = 50
dropout_rate = 0.2
image_size = (128, 128)

# Data Generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 19032 images belonging to 4 classes.
# Found 4756 images belonging to 4 classes.
# Found 3400 images belonging to 4 classes.

# %%
# Model Definition
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128,128, 3))
base_model.trainable = False  # Freeze the base model
#for layers in base_model.layers[:100]:
 #   layers.trainable = False
#for layers in base_model.layers[100:]:
#    layers.trainable = True


model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(dropout_rate),
    Dense(4, activation='softmax')  # 4 classes
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Training
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732125655.488633     122 service.cc:145] XLA service 0x7f69b000bca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732125655.488703     122 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1732125655.488709     122 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   1/595 ━━━━━━━━━━━━━━━━━━━━ 1:39:25 10s/step - accuracy: 0.1875 - loss: 1.9410
# I0000 00:00:1732125663.493066     122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 114s 175ms/step - accuracy: 0.3092 - loss: 1.3892 - val_accuracy: 0.4315 - val_loss: 1.2622 - learning_rate: 0.0010
# Epoch 2/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.4050 - loss: 1.2664 - val_accuracy: 0.4609 - val_loss: 1.2162 - learning_rate: 0.0010
# Epoch 3/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.4411 - loss: 1.2322 - val_accuracy: 0.4809 - val_loss: 1.1918 - learning_rate: 0.0010
# Epoch 4/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.4515 - loss: 1.2145 - val_accuracy: 0.4918 - val_loss: 1.1616 - learning_rate: 0.0010
# Epoch 5/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 157ms/step - accuracy: 0.4693 - loss: 1.1899 - val_accuracy: 0.5181 - val_loss: 1.1538 - learning_rate: 0.0010
# Epoch 6/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.4757 - loss: 1.1771 - val_accuracy: 0.5063 - val_loss: 1.1388 - learning_rate: 0.0010
# Epoch 7/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.4737 - loss: 1.1645 - val_accuracy: 0.5223 - val_loss: 1.1276 - learning_rate: 0.0010
# Epoch 8/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.4795 - loss: 1.1678 - val_accuracy: 0.5093 - val_loss: 1.1143 - learning_rate: 0.0010
# Epoch 9/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 98s 164ms/step - accuracy: 0.4943 - loss: 1.1543 - val_accuracy: 0.5114 - val_loss: 1.1160 - learning_rate: 0.0010
# Epoch 10/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.4812 - loss: 1.1506 - val_accuracy: 0.5235 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 11/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.4966 - loss: 1.1442 - val_accuracy: 0.5286 - val_loss: 1.1067 - learning_rate: 0.0010
# Epoch 12/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.4882 - loss: 1.1506 - val_accuracy: 0.5473 - val_loss: 1.0848 - learning_rate: 0.0010
# Epoch 13/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.4879 - loss: 1.1435 - val_accuracy: 0.5309 - val_loss: 1.0943 - learning_rate: 0.0010
# Epoch 14/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.4873 - loss: 1.1460 - val_accuracy: 0.5324 - val_loss: 1.0831 - learning_rate: 0.0010
# Epoch 15/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.4994 - loss: 1.1304 - val_accuracy: 0.5320 - val_loss: 1.0833 - learning_rate: 0.0010
# Epoch 16/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.4955 - loss: 1.1287 - val_accuracy: 0.5263 - val_loss: 1.0794 - learning_rate: 0.0010
# Epoch 17/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5011 - loss: 1.1274 - val_accuracy: 0.5500 - val_loss: 1.0652 - learning_rate: 0.0010
# Epoch 18/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5062 - loss: 1.1238 - val_accuracy: 0.5538 - val_loss: 1.0644 - learning_rate: 0.0010
# Epoch 19/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 153ms/step - accuracy: 0.5046 - loss: 1.1235 - val_accuracy: 0.5580 - val_loss: 1.0687 - learning_rate: 0.0010
# Epoch 20/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5008 - loss: 1.1237 - val_accuracy: 0.5357 - val_loss: 1.0707 - learning_rate: 0.0010
# Epoch 21/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5016 - loss: 1.1281 - val_accuracy: 0.5526 - val_loss: 1.0695 - learning_rate: 0.0010
# Epoch 22/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.5044 - loss: 1.1138 - val_accuracy: 0.5570 - val_loss: 1.0550 - learning_rate: 2.0000e-04
# Epoch 23/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.5032 - loss: 1.1197 - val_accuracy: 0.5624 - val_loss: 1.0540 - learning_rate: 2.0000e-04
# Epoch 24/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 153ms/step - accuracy: 0.5049 - loss: 1.1206 - val_accuracy: 0.5658 - val_loss: 1.0559 - learning_rate: 2.0000e-04
# Epoch 25/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5138 - loss: 1.1072 - val_accuracy: 0.5578 - val_loss: 1.0564 - learning_rate: 2.0000e-04
# Epoch 26/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5018 - loss: 1.1081 - val_accuracy: 0.5530 - val_loss: 1.0635 - learning_rate: 2.0000e-04
# Epoch 27/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5045 - loss: 1.1128 - val_accuracy: 0.5530 - val_loss: 1.0508 - learning_rate: 4.0000e-05
# Epoch 28/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.5076 - loss: 1.1127 - val_accuracy: 0.5620 - val_loss: 1.0536 - learning_rate: 4.0000e-05
# Epoch 29/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 94s 156ms/step - accuracy: 0.5109 - loss: 1.1112 - val_accuracy: 0.5515 - val_loss: 1.0633 - learning_rate: 4.0000e-05
# Epoch 30/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 155ms/step - accuracy: 0.4959 - loss: 1.1226 - val_accuracy: 0.5597 - val_loss: 1.0524 - learning_rate: 4.0000e-05
# Epoch 31/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 92s 154ms/step - accuracy: 0.5111 - loss: 1.1126 - val_accuracy: 0.5532 - val_loss: 1.0562 - learning_rate: 8.0000e-06
# Epoch 32/50
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 93s 154ms/step - accuracy: 0.5066 - loss: 1.1163 - val_accuracy: 0.5521 - val_loss: 1.0576 - learning_rate: 8.0000e-06

# %%
# Evaluation
train_loss, train_acc = model.evaluate(train_generator, verbose=0)
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Train Accuracy: {train_acc:.2f}, Test Accuracy: {test_acc:.2f}")
# Out:
# Train Accuracy: 0.56, Test Accuracy: 0.59

# %%
# Classification Report and Confusion Matrix
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.54      0.70      0.61       896
# ModerateDemented       0.74      0.86      0.80       648
#      NonDemented       0.59      0.64      0.61       960
# VeryMildDemented       0.50      0.25      0.33       896
#
#         accuracy                           0.59      3400
#        macro avg       0.59      0.61      0.59      3400
#     weighted avg       0.58      0.59      0.57      3400

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(class_labels)):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(len(class_labels)):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Plotting Loss and Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
